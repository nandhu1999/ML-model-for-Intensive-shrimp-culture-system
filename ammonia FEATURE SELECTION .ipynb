# %% [markdown]
# ## Exploratory Data Analysis & Feature selection

# %%
## import required libraries
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
sns.set_style({'font.family':'serif','font.serif':'Times New Roman'})

# %%
## import the dataset
df=pd.read_excel('data1.xlsx')
df.head()
# Out:
#    DOC  Salinity (ppt)  SDR (cm) Water colour  Water level (cm)  TSS (ml/L)  \
# 0    1              16        50          lbr               120         1.0
# 1    2              16        48          lgr               120         2.0
# 2    3              16        55          lbr               132         0.5
# 3    4              16        60          lbr               128         0.5
# 4    5              16        45          lbr               126         0.5
#
#    Average PH  Average DO (ppm)  Running aerator (HP)  TDF (kg)  ABW (gm)  \
# 0        8.25          5.783333                    56       1.7     0.008
# 1        8.25          5.600000                    31       2.4       NaN
# 2        8.05          5.333333                    29       3.4       NaN
# 3        8.00          5.466667                    44       4.2       NaN
# 4        8.00          5.433333                    57       5.0       NaN
#
#    Water temperature (˚C)  PH change  Ammonia (ppm)  Water exchange (cm)
# 0                   29.10        0.3          0.026                    0
# 1                   28.65        0.1          0.028                    0
# 2                   28.10        0.1            NaN                    5
# 3                   28.40        0.0          0.018                    0
# 4                   28.15        0.2          0.030                    0

# %%
data=pd.DataFrame(df.dtypes)
data=data.rename(columns={0:'DataType'})
data
# Out:
#                        DataType
# DOC                       int64
# Salinity (ppt)            int64
# SDR (cm)                  int64
# Water colour             object
# Water level (cm)          int64
# TSS (ml/L)              float64
# Average PH              float64
# Average DO (ppm)        float64
# Running aerator (HP)      int64
# TDF (kg)                float64
# ABW (gm)                float64
# Water temperature (˚C)  float64
# PH change               float64
# Ammonia (ppm)           float64
# Water exchange (cm)       int64

# %%
df['Water colour'].value_counts()
# Out:
# br     145
# lgr     74
# lbr     50
# gr      41
# yg      39
# dgr     37
# dbr     14
# Name: Water colour, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
enc=LabelEncoder()
enc.fit(df['Water colour'])
df['Water colour']=enc.transform(df['Water colour'])
df
# Out:
#      DOC  Salinity (ppt)  SDR (cm)  Water colour  Water level (cm)  \
# 0      1              16        50             4               120
# 1      2              16        48             5               120
# 2      3              16        55             4               132
# 3      4              16        60             4               128
# 4      5              16        45             4               126
# ..   ...             ...       ...           ...               ...
# 395   96              22        18             0               126
# 396   97              23        22             0               130
# 397   98              23        23             5               128
# 398   99              23        24             5               125
# 399  100              23        20             5               120
#
#      TSS (ml/L)  Average PH  Average DO (ppm)  Running aerator (HP)  TDF (kg)  \
# 0           1.0        8.25          5.783333                    56       1.7
# 1           2.0        8.25          5.600000                    31       2.4
# 2           0.5        8.05          5.333333                    29       3.4
# 3           0.5        8.00          5.466667                    44       4.2
# 4           0.5        8.00          5.433333                    57       5.0
# ..          ...         ...               ...                   ...       ...
# 395         6.0        7.70          4.776667                   934     460.0
# 396         4.0        7.75          4.716667                  1128     400.0
# 397         5.0        7.75          5.333333                   922     410.0
# 398         6.0        7.70          4.850000                   960     400.0
# 399         5.0        7.70          4.950000                   126     400.0
#
#      ABW (gm)  Water temperature (˚C)  PH change  Ammonia (ppm)  \
# 0       0.008                   29.10        0.3          0.026
# 1         NaN                   28.65        0.1          0.028
# 2         NaN                   28.10        0.1            NaN
# 3         NaN                   28.40        0.0          0.018
# 4         NaN                   28.15        0.2          0.030
# ..        ...                     ...        ...            ...
# 395       NaN                   30.35        0.0          0.054
# 396       NaN                   29.15        0.1            NaN
# 397       NaN                   27.70        0.1            NaN
# 398       NaN                   28.55        0.2          0.039
# 399    19.500                   28.85        0.0          0.054
#
#      Water exchange (cm)
# 0                      0
# 1                      0
# 2                      5
# 3                      0
# 4                      0
# ..                   ...
# 395                    0
# 396                    0
# 397                    0
# 398                    0
# 399                    0
#
# [400 rows x 15 columns]

# %% [markdown]
# ## Handling Missing value

# %%
df.isnull()
# Out:
#        DOC  Salinity (ppt)  SDR (cm)  Water colour  Water level (cm)  \
# 0    False           False     False         False             False
# 1    False           False     False         False             False
# 2    False           False     False         False             False
# 3    False           False     False         False             False
# 4    False           False     False         False             False
# ..     ...             ...       ...           ...               ...
# 395  False           False     False         False             False
# 396  False           False     False         False             False
# 397  False           False     False         False             False
# 398  False           False     False         False             False
# 399  False           False     False         False             False
#
#      TSS (ml/L)  Average PH  Average DO (ppm)  Running aerator (HP)  TDF (kg)  \
# 0         False       False             False                 False     False
# 1         False       False             False                 False     False
# 2         False       False             False                 False     False
# 3         False       False             False                 False     False
# 4         False       False             False                 False     False
# ..          ...         ...               ...                   ...       ...
# 395       False       False             False                 False     False
# 396       False       False             False                 False     False
# 397       False       False             False                 False     False
# 398       False       False             False                 False     False
# 399       False       False             False                 False     False
#
#      ABW (gm)  Water temperature (˚C)  PH change  Ammonia (ppm)  \
# 0       False                   False      False          False
# 1        True                   False      False          False
# 2        True                   False      False           True
# 3        True                   False      False          False
# 4        True                   False      False          False
# ..        ...                     ...        ...            ...
# 395      True                   False      False          False
# 396      True                   False      False           True
# 397      True                   False      False           True
# 398      True                   False      False          False
# 399     False                   False      False          False
#
#      Water exchange (cm)
# 0                  False
# 1                  False
# 2                  False
# 3                  False
# 4                  False
# ..                   ...
# 395                False
# 396                False
# 397                False
# 398                False
# 399                False
#
# [400 rows x 15 columns]

# %%
df.isnull().sum()
# Out:
# DOC                         0
# Salinity (ppt)              0
# SDR (cm)                    0
# Water colour                0
# Water level (cm)            0
# TSS (ml/L)                  0
# Average PH                  0
# Average DO (ppm)            0
# Running aerator (HP)        0
# TDF (kg)                    0
# ABW (gm)                  343
# Water temperature (˚C)      0
# PH change                   0
# Ammonia (ppm)             219
# Water exchange (cm)         0
# dtype: int64

# %%
df=df.interpolate(method='linear', order=5)

# %%
df.describe()
# Out:
#              DOC  Salinity (ppt)    SDR (cm)  Water colour  Water level (cm)  \
# count  400.00000      400.000000  400.000000    400.000000        400.000000
# mean    50.50000       18.310000   24.630000      2.537500        128.142500
# std     28.90222        4.781847    8.021156      2.244144          8.769804
# min      1.00000       10.000000   10.000000      0.000000        100.000000
# 25%     25.75000       14.750000   20.000000      0.000000        122.000000
# 50%     50.50000       19.000000   23.000000      3.000000        129.000000
# 75%     75.25000       21.000000   28.000000      5.000000        134.000000
# max    100.00000       28.000000   60.000000      6.000000        154.000000
#
#        TSS (ml/L)  Average PH  Average DO (ppm)  Running aerator (HP)  \
# count  400.000000  400.000000        400.000000            400.000000
# mean     4.558750    7.839937          5.222921            421.025000
# std      3.428587    0.321191          0.630881            280.711563
# min      0.000000    7.100000          4.200000             29.000000
# 25%      1.950000    7.650000          4.750000            193.750000
# 50%      4.000000    7.800000          5.133333            353.000000
# 75%      6.500000    8.050000          5.550000            614.000000
# max     15.000000    8.800000          7.350000           1269.000000
#
#          TDF (kg)    ABW (gm)  Water temperature (˚C)   PH change  \
# count  400.000000  400.000000              400.000000  400.000000
# mean   216.263750    9.631809               29.715813    0.164725
# std    179.005177    7.755254                1.080979    0.133219
# min      1.700000    0.007000               27.200000    0.000000
# 25%     85.150000    2.041952               29.150000    0.100000
# 50%    155.000000    8.575000               29.725000    0.100000
# 75%    392.500000   16.857143               30.462500    0.200000
# max    630.000000   25.500000               31.650000    0.600000
#
#        Ammonia (ppm)  Water exchange (cm)
# count     400.000000           400.000000
# mean        0.076820             2.205000
# std         0.074884             2.151639
# min         0.010000             0.000000
# 25%         0.038458             0.000000
# 50%         0.054500             2.000000
# 75%         0.080000             4.000000
# max         0.500000            10.000000

# %%
corr=df.corr()
plt.figure(figsize=(15, 13))
plt.rcParams.update({'font.size':12})

sns.heatmap(corr[(corr>=0) | (corr<=-0)], cmap='viridis', vmax=1.0, vmin=-1, linewidths=0.1, annot=True, annot_kws={"size":10},square=True);

# %%
corr=df.corr()
plt.figure(figsize=(15, 13))

sns.heatmap(corr[(corr>=0.3) | (corr<=-0.3)], cmap='viridis', vmax=1.0, vmin=-1, linewidths=0.1, annot=True, annot_kws={"size":10},square=True);

# %%
x=df.drop(columns=['Ammonia (ppm)'],axis=1)
x
# Out:
#      DOC  Salinity (ppt)  SDR (cm)  Water colour  Water level (cm)  \
# 0      1              16        50             4               120
# 1      2              16        48             5               120
# 2      3              16        55             4               132
# 3      4              16        60             4               128
# 4      5              16        45             4               126
# ..   ...             ...       ...           ...               ...
# 395   96              22        18             0               126
# 396   97              23        22             0               130
# 397   98              23        23             5               128
# 398   99              23        24             5               125
# 399  100              23        20             5               120
#
#      TSS (ml/L)  Average PH  Average DO (ppm)  Running aerator (HP)  TDF (kg)  \
# 0           1.0        8.25          5.783333                    56       1.7
# 1           2.0        8.25          5.600000                    31       2.4
# 2           0.5        8.05          5.333333                    29       3.4
# 3           0.5        8.00          5.466667                    44       4.2
# 4           0.5        8.00          5.433333                    57       5.0
# ..          ...         ...               ...                   ...       ...
# 395         6.0        7.70          4.776667                   934     460.0
# 396         4.0        7.75          4.716667                  1128     400.0
# 397         5.0        7.75          5.333333                   922     410.0
# 398         6.0        7.70          4.850000                   960     400.0
# 399         5.0        7.70          4.950000                   126     400.0
#
#       ABW (gm)  Water temperature (˚C)  PH change  Water exchange (cm)
# 0     0.008000                   29.10        0.3                    0
# 1     0.022571                   28.65        0.1                    0
# 2     0.037143                   28.10        0.1                    5
# 3     0.051714                   28.40        0.0                    0
# 4     0.066286                   28.15        0.2                    0
# ..         ...                     ...        ...                  ...
# 395  19.100000                   30.35        0.0                    0
# 396  19.200000                   29.15        0.1                    0
# 397  19.300000                   27.70        0.1                    0
# 398  19.400000                   28.55        0.2                    0
# 399  19.500000                   28.85        0.0                    0
#
# [400 rows x 14 columns]

# %%
y=df['Ammonia (ppm)']
y
# Out:
# 0      0.026
# 1      0.028
# 2      0.023
# 3      0.018
# 4      0.030
#        ...
# 395    0.054
# 396    0.049
# 397    0.044
# 398    0.039
# 399    0.054
# Name: Ammonia (ppm), Length: 400, dtype: float64

# %% [markdown]
# ## Feature selection

# %%
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import SelectKBest

# %% [markdown]
# ## Mutual Information Regression

# %%
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import mutual_info_regression

# %%
top_col=SelectKBest(mutual_info_regression,k=4)
model=top_col.fit(x, y)
x.columns[top_col.get_support()]
# Out:
# Index(['DOC', 'Salinity (ppt)', 'TDF (kg)', 'ABW (gm)'], dtype='object')

# %%
dfscore=pd.DataFrame(model.scores_)
dfcolumn=pd.DataFrame(x.columns)
featurescore=pd.concat([dfcolumn,dfscore], axis=1)
featurescore.columns=['Parameters','Score']
featurescore
# Out:
#                 Parameters     Score
# 0                      DOC  0.415373
# 1           Salinity (ppt)  0.328740
# 2                 SDR (cm)  0.165389
# 3             Water colour  0.063912
# 4         Water level (cm)  0.128869
# 5               TSS (ml/L)  0.154899
# 6               Average PH  0.123256
# 7         Average DO (ppm)  0.064673
# 8     Running aerator (HP)  0.308202
# 9                 TDF (kg)  0.335457
# 10                ABW (gm)  0.502315
# 11  Water temperature (˚C)  0.044025
# 12               PH change  0.047331
# 13     Water exchange (cm)  0.038757

# %%
data={'DOC':0.415,'Salinity(ppt)':0.328,'SDR(cm)':0.165,
      'Water colour':0.063,'Water level(cm)':0.128,'TSS(ml/L)':0.155,
      'Average PH':0.123,'Average DO(ppm)':0.065,'Running aerator(HP)':0.308,
      'TDF(kg)':0.335, 'ABW(gm)':0.502,
      'Water temperature(˚C)':0.044,
      'PH change':0.47,
      'Water exchange(cm)':0.039}
features=list(data.keys())
scores=list(data.values())
fig,ax=plt.subplots(figsize=(10,12))
ax.barh(features, scores)

for s in ['top', 'bottom', 'left', 'right']:
    ax.spines[s].set_visible(False)
    
ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')

ax.xaxis.set_tick_params(pad =5)
ax.yaxis.set_tick_params(pad =10)


ax.invert_yaxis()

for i in ax.patches:
    plt.text(i.get_width(), i.get_y()+0.5, str(round((i.get_width()),3)), fontsize=10,fontweight='bold',color='grey')
plt.show()

# %% [markdown]
# ## Spearman Ranking Correlation

# %%
from numpy.random import randn
from numpy.random import seed
from scipy.stats import spearmanr

seed(1)
out=df['Ammonia (ppm)']
d1=df['DOC']
d2=df['Salinity (ppt)']
d3=df['SDR (cm)']
d4=df['Water colour']
d5=df['Water level (cm)']
d6=df['TSS (ml/L)']
d7=df['Average PH']
d8=df['Average DO (ppm)']
d9=df['Running aerator (HP)']
d10=df['TDF (kg)']
d11=df['ABW (gm)']
d12=df['Water temperature (˚C)']
d13=df['PH change']
d14=df['Water exchange (cm)']

corr0,_=spearmanr(d1,out)
corr1,_=spearmanr(d2,out)
corr2,_=spearmanr(d3,out)
corr3,_=spearmanr(d4,out)
corr4,_=spearmanr(d5,out)
corr5,_=spearmanr(d6,out)
corr6,_=spearmanr(d7,out)
corr7,_=spearmanr(d8,out)
corr8,_=spearmanr(d9,out)
corr9,_=spearmanr(d10,out)
corr10,_=spearmanr(d11,out)
corr11,_=spearmanr(d12,out)
corr12,_=spearmanr(d13,out)
corr13,_=spearmanr(d14,out)

# %%
print('Spearmans correlation of DOC : %.3F' % corr0)
print('Spearmans correlation of Salinity : %.3F' % corr1)
print('Spearmans correlation of SDR(cm) : %.3F' % corr2)
print('Spearmans correlation of Water colour: %.3F' % corr3)
print('Spearmans correlation of Water level(cm) : %.3F' % corr4)
print('Spearmans correlation of TSS(ml/L) : %.3F' % corr5)
print('Spearmans correlation of Average PH : %.3F' % corr6)
print('Spearmans correlation of Average DO(ppm) : %.3F' % corr7)
print('Spearmans correlation of Running aerator(HP) : %.3F' % corr8)
print('Spearmans correlation of TDF (kg) : %.3F' % corr9)
print('Spearmans correlation of ABW(gm) : %.3F' % corr10)
print('Spearmans correlation of Water temperature(˚C) : %.3F' % corr11)
print('Spearmans correlation of PH change  : %.3F' % corr12)
print('Spearmans correlation of Water exchange(cm) : %.3F' % corr13)
# Out:
# Spearmans correlation of DOC : 0.302
# Spearmans correlation of Salinity : 0.200
# Spearmans correlation of SDR(cm) : -0.223
# Spearmans correlation of Water colour: -0.127
# Spearmans correlation of Water level(cm) : 0.073
# Spearmans correlation of TSS(ml/L) : 0.148
# Spearmans correlation of Average PH : -0.186
# Spearmans correlation of Average DO(ppm) : -0.150
# Spearmans correlation of Running aerator(HP) : 0.078
# Spearmans correlation of TDF (kg) : 0.225
# Spearmans correlation of ABW(gm) : 0.322
# Spearmans correlation of Water temperature(˚C) : -0.116
# Spearmans correlation of PH change  : 0.093
# Spearmans correlation of Water exchange(cm) : 0.261

# %% [markdown]
# ## Pairplot

# %%
for i in range(0, len(df.columns),5):
    sns.pairplot(data=df,x_vars=df.columns[i:i+4], y_vars=['Ammonia (ppm)'])

# %%
df.to_excel('ammonia.xlsx')
